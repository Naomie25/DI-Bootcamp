# %% [markdown]
# <a href="https://colab.research.google.com/github/Naomie25/DI-Bootcamp/blob/main/ExerciceXP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise 1: Introduction to Data Analysis (Easy)
#
# What is data analysis?
# Data anlysis is a process of inspection, cleaning,transforming and modeling data to discover useful information,information concluions and to support decison-making
#
# Why is data analysis important in modern contexts?
# It is important because of: Better Decisions,Efficiency,Competitive Edge,Personalization, Innovation, Risk Detection, Public Good
#
# List and describe three areas where data analysis is applied today.
# Data analysis is widely used in:
# Healthcare – To improve diagnosis, treatment, and patient care.
# Finance – For detecting fraud and managing risks.
# Marketing – To understand customers and create targeted campaigns.

# %% [markdown]
# Exercise 2: Dataset Loading and Initial Analysis

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6f0d076a-bc84-44f3-b787-189289b9c5ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f0d076a-bc84-44f3-b787-189289b9c5ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/Mental health Depression disorder Data.csv')
# Out:
# <ipython-input-16-93439c060445>:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Mental health Depression disorder Data.csv')

# %%
df.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108553 entries, 0 to 108552
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      108553 non-null  int64
#  1   Entity                     108553 non-null  object
#  2   Code                       103141 non-null  object
#  3   Year                       108553 non-null  object
#  4   Schizophrenia (%)          25875 non-null   object
#  5   Bipolar disorder (%)       19406 non-null   object
#  6   Eating disorders (%)       100236 non-null  object
#  7   Anxiety disorders (%)      6468 non-null    float64
#  8   Drug use disorders (%)     6468 non-null    float64
#  9   Depression (%)             6468 non-null    float64
#  10  Alcohol use disorders (%)  6468 non-null    float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 9.1+ MB

# %%
df2 = pd.read_csv('/content/Mental health Depression disorder Data.csv')
# Out:
# <ipython-input-3-e9c6aa403fba>:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('/content/Mental health Depression disorder Data.csv')

# %%
df2.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108553 entries, 0 to 108552
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      108553 non-null  int64
#  1   Entity                     108553 non-null  object
#  2   Code                       103141 non-null  object
#  3   Year                       108553 non-null  object
#  4   Schizophrenia (%)          25875 non-null   object
#  5   Bipolar disorder (%)       19406 non-null   object
#  6   Eating disorders (%)       100236 non-null  object
#  7   Anxiety disorders (%)      6468 non-null    float64
#  8   Drug use disorders (%)     6468 non-null    float64
#  9   Depression (%)             6468 non-null    float64
#  10  Alcohol use disorders (%)  6468 non-null    float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 9.1+ MB

# %%
df3=pd.read_csv('/content/clean_dataset.csv')

# %%
df3.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
df3.describe()
# Out:
#            Gender         Age        Debt     Married  BankCustomer  \
# count  690.000000  690.000000  690.000000  690.000000    690.000000
# mean     0.695652   31.514116    4.758725    0.760870      0.763768
# std      0.460464   11.860245    4.978163    0.426862      0.425074
# min      0.000000   13.750000    0.000000    0.000000      0.000000
# 25%      0.000000   22.670000    1.000000    1.000000      1.000000
# 50%      1.000000   28.460000    2.750000    1.000000      1.000000
# 75%      1.000000   37.707500    7.207500    1.000000      1.000000
# max      1.000000   80.250000   28.000000    1.000000      1.000000
#
#        YearsEmployed  PriorDefault    Employed  CreditScore  DriversLicense  \
# count     690.000000    690.000000  690.000000    690.00000      690.000000
# mean        2.223406      0.523188    0.427536      2.40000        0.457971
# std         3.346513      0.499824    0.495080      4.86294        0.498592
# ...

# %%
df4=pd.read_csv('/content/crx.csv')

# %%
df4.head()
# Out:
#    b  30.83      0  u  g  w  v  1.25  t t.1  01  f g.1  00202  0.1  +
# 0  a  58.67  4.460  u  g  q  h  3.04  t   t   6  f   g  00043  560  +
# 1  a  24.50  0.500  u  g  q  h  1.50  t   f   0  f   g  00280  824  +
# 2  b  27.83  1.540  u  g  w  v  3.75  t   t   5  t   g  00100    3  +
# 3  b  20.17  5.625  u  g  w  v  1.71  t   f   0  f   s  00120    0  +
# 4  b  32.08  4.000  u  g  m  v  2.50  t   f   0  t   g  00360    0  +

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   b       689 non-null    object
#  1   30.83   689 non-null    object
#  2   0       689 non-null    float64
#  3   u       689 non-null    object
#  4   g       689 non-null    object
#  5   w       689 non-null    object
#  6   v       689 non-null    object
#  7   1.25    689 non-null    float64
#  8   t       689 non-null    object
#  9   t.1     689 non-null    object
#  10  01      689 non-null    int64
#  11  f       689 non-null    object
#  12  g.1     689 non-null    object
#  13  00202   689 non-null    object
#  14  0.1     689 non-null    int64
#  15  +       689 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 86.3+ KB

# %% [markdown]
# Exercice 3

# %% [markdown]
# Index: Quantitative,Year: Quantitative, Avg hrs per day: Quantitative, sleeping: Qualitative,Standard Error: Quantitative, Type of Days: Qualitative, Age Group: Quantitative, Activity: Qualitative, Sex: Qualitative

# %% [markdown]
# Mental Health:
# Index: Quantitative
# Entity:Qualitative
# Code: Qualitative
# Year:Quantitative
# Schizophrenia: Quantitative
# Bipolar Disorder: Quantitative
# Eating disorder: Qualitative
# Anxiety: Quantitative
# Drug: Quantitative
# Depression and alcohol: Quantitative

# %% [markdown]
# Clean_dataset:
# Gender: Qualitative
# Age: Quantitative
# Debt: Quantitative
# Married: Qualitative
# BankCustomer: Qualitative
# Industry: Qualitative
# Ethnicity: Qualitative
# yearsEmployed: quantitative
# priorDefault: Qualitative
# employed: Qualitative
# creditScore: quantitative
# driversLicense: Qualitative
# citizen: Qualitative
# zipcode: quantitative
# income: quantitative
# approved: qualitative

# %% [markdown]
# Exercice 4

# %%
# !ls -l kaggle.json
import os

os.makedirs('/root/.kaggle', exist_ok=True)
# !mv kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# ls: cannot access 'kaggle.json': No such file or directory
# mv: cannot stat 'kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d uciml/iris
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/iris
# License(s): CC0-1.0
# ...
#   0% 0.00/3.60k [00:00<?, ?B/s]
# 100% 3.60k/3.60k [00:00<00:00, 17.8MB/s]

# %%
import zipfile

with zipfile.ZipFile("iris.zip","r") as zip_ref:
    zip_ref.extractall("iris_data")

import pandas as pd

iris = pd.read_csv("iris_data/Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Id: Quantitative
# SepalLengthCm:Quantitative
# SepalWidthCm:Quantitative
# PetalLengthCm:Quantitative
# PetalWidthCm:Quantitative
# Species: Qualitative. Most of the columns are quantitative because they are numerical data that can be measured. Species is qualitative because it is  a non-numerical

# %% [markdown]
# Exercice 5

# %%
mean_age = iris['SepalLengthCm'].mean()
print(mean_age)
# Out:
# 5.843333333333334

# %%
median=iris['PetalLengthCm'].median()
print(median)
# Out:
# 4.35

# %%
mode=iris['PetalLengthCm'].mode()
print(mode)
# Out:
# 0    1.5
# Name: PetalLengthCm, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(iris['SepalLengthCm'],iris['PetalLengthCm'], iris['PetalWidthCm'])
plt.show()

# %% [markdown]
# Exercise 6: Basic Observation Skills in Data Analysis

# %% [markdown]
# Columns like Average Sleep Hours, Age Group, Gender, Employment, and Education are excellent for various comparisons and statistical analysis.
