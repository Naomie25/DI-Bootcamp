# %% [markdown]
# <a href="https://colab.research.google.com/github/Naomie25/DI-Bootcamp/blob/main/Week3_Day4_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Creating Basic Plots

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y, color='green', linestyle='dashed', linewidth=2, marker='o', markerfacecolor='blue', markersize=12)
plt.show()

# %% [markdown]
# Bar Charts

# %%
categories = ['Apples', 'Bananas', 'Oranges', 'Grapes']
values = [20, 35, 30, 15]

plt.bar(categories, values)
plt.title('Fruit Sales Data')
plt.xlabel('Fruit')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Customizing Bar Charts

# %%
plt.bar(categories, values, color=['red', 'green', 'blue', 'purple'], edgecolor='black', hatch='/')
plt.title('Customized Fruit Sales Data')
plt.xlabel('Fruit')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Histograms

# %%
import numpy as np

data = np.random.normal(0, 1, 1000)
plt.hist(data, bins=15, edgecolor='black')
plt.title("Histogram of Normally Distributed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Pie Charts

# %%
brands = ['Apple', 'Samsung', 'Huawei', 'Xiaomi', 'Others']
market_share = [40, 30, 15, 10, 5]

plt.pie(market_share, labels=brands, autopct='%1.1f%%')
plt.title('Smartphone Market Share 2023')
plt.show()

plt.bar(brands,market_share)
plt.title('Smartphone Market Share 2023')
plt.show()

# %% [markdown]
# Customizing Pie Charts

# %%
explode = (0.1, 0, 0, 0, 0)
plt.pie(market_share, labels=brands, autopct='%1.1f%%', explode=explode)
plt.show()

# %% [markdown]
# Creating Box Plots

# %%
import numpy as np

data = np.random.randn(100)
plt.boxplot(data)
plt.title('Basic Box Plot')
plt.ylabel('Values')
plt.show()

# %%
import pandas as pd
df= pd.DataFrame({'market share':market_share,'brands':brands})
df
# Out:
#    market share   brands
# 0            40    Apple
# 1            30  Samsung
# 2            15   Huawei
# 3            10   Xiaomi
# 4             5   Others

# %% [markdown]
# Subplots and Multiple Axes

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot([1, 2, 3], [1, 4, 9])
ax1.set_title('First Subplot')
ax2.plot([1, 2, 3], [1, 2, 3])
ax2.set_title('Second Subplot')
plt.show()

# %% [markdown]
# Line Plot Exercise

# %%
import numpy as np
x=np.array(list(range(11)))
y=x**2
plt.plot(x,y)
plt.show()

# %% [markdown]
# Bar Chart Exercise

# %%
products = ['Mac', 'Phone', 'IMac', 'Ipad']
sales = [100, 1000, 280, 900]

plt.bar(products, sales)
plt.title('Devices of Apple')
plt.xlabel('Products')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Histogram Exercise

# %%
import numpy as np
import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(100)  # Generates 100 random values between 0 and 1
plt.hist(x, edgecolor='black')
plt.title("Histogram of Random Values")
plt.show()

# %% [markdown]
# Pie Chart Exercise

# %%
# Data
activities = ['Work', 'Sleep', 'Leisure', 'Exercise', 'Others']
hours = [8, 7, 4, 2, 3]
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0']

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(hours, labels=activities, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Daily Time Distribution')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
plt.show()

# %% [markdown]
# SeaBorn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample data
data = sns.load_dataset('tips')
sns.histplot(data['total_bill'], bins=20, color='skyblue')
plt.title('Histogram of Total Bill')
plt.show()

# %% [markdown]
# Kernel Density Estimation (KDE) Plots

# %%
sns.kdeplot(data['total_bill'], shade=True, color='purple')
plt.title('KDE of Total Bill')
plt.show()
# Out:
# <ipython-input-36-c50108c949cc>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['total_bill'], shade=True, color='purple')

# %% [markdown]
# Exploring Bivariate Distributions

# %%
sns.jointplot(x='total_bill', y='tip', data=data, kind='scatter', color='green')
plt.show()

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Categorical Data Visualization

# %% [markdown]
# Bar Plots

# %%
titanic = sns.load_dataset('titanic')
sns.barplot(x='class', y='survived', data=titanic, palette='Blues')
plt.title('Survival Rate by Class')
plt.show()
# Out:
# <ipython-input-39-24a7d9d81cac>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='class', y='survived', data=titanic, palette='Blues')

# %% [markdown]
# Box Plots

# %%
sns.boxplot(x='class', y='age', data=titanic, palette='Set3')
plt.title('Age Distribution by Class')
plt.show()
# Out:
# <ipython-input-40-6c977577a5c9>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class', y='age', data=titanic, palette='Set3')

# %% [markdown]
# Violin Plots

# %%
sns.violinplot(x='class', y='age', data=titanic, palette='muted')
plt.title('Age Distribution by Class')
plt.show()
# Out:
# <ipython-input-41-ba8ad66e93f4>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='class', y='age', data=titanic, palette='muted')

# %% [markdown]
# Scatter Plots and Joint Plots

# %% [markdown]
# Scatter Plots with Regression Lines

# %%
sns.lmplot(x='total_bill', y='tip', data=data, aspect=1.5, height=5)
plt.title('Scatter Plot with Regression Line')
plt.show()
